# %%
import pandas as pd
import numpy as np
df = pd.read_csv('test_data.csv')
final_df=pd.DataFrame()
feature_dict = {i:label for i,label in zip(
                range(21),
                  ('load_type',
                   'truck_type',
                   'route_type',
                   'rainfall',
                   'temperature',
                   'temp_type',
                   'tyre1_press',
                   'tyre1_press_stat',
                   'tyre2_press',
                   'tyre2_press_stat',
                   'tyre3_press',
                   'tyre3_press_stat',
                   'tyre4_press',
                   'tyre4_press_stat',
                   'tyre5_press',
                   'tyre5_press_stat',
                   'tyre6_press',
                   'tyre6_press_stat',
                   'avg_speed',
                   'time',
                   'fuel',
                   ))}

df.columns = [l for i,l in sorted(feature_dict.items())] + [
                   'tyre1_condition',
                   'tyre2_condition',
                   'tyre3_condition',
                   'tyre4_condition',
                   'tyre5_condition',
                   'tyre6_condition',
                   'efficiency',      ]
df.dropna(how="all", inplace=True) # to drop the empty line at file-end

df.tail()
# Out:
#       load_type truck_type route_type rainfall  temperature temp_type  \
# 245  Heavy Load        FTL      Bumpy        N           27    Normal
# 246    Moderate        LCV      Hilly        N           25    Normal
# 247   Full Load        FTL      Plain        N           30    Normal
# 248  Heavy Load        LCV      Bumpy        N           28    Normal
# 249    Moderate        LCV      Hilly        N           26    Normal
#
#      tyre1_press tyre1_press_stat  tyre2_press tyre2_press_stat     ...      \
# 245           42          Correct           51          Correct     ...
# 246           58          Correct           62          Correct     ...
# 247           47          Correct           45          Correct     ...
# 248           44          Correct           30              Low     ...
# 249           55          Correct           45          Correct     ...
#
#      avg_speed time  fuel tyre1_condition  tyre2_condition tyre3_condition  \
# ...

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

print('\n CHI 2 ANALYSIS\n')
from prettytable import PrettyTable
t1 = PrettyTable(['Feature', 'Stat','Critical','Result'])
t2 = PrettyTable(['Feature', 'Stat','Critical','Result'])
t3 = PrettyTable(['Feature', 'Stat','Critical','Result'])
t4 = PrettyTable(['Feature', 'Stat','Critical','Result'])
t5 = PrettyTable(['Feature', 'Stat','Critical','Result'])
t6 = PrettyTable(['Feature', 'Stat','Critical','Result'])
print('\n Tyre 1 \n')
stat1=[]
crit1=[]
stat2=[]
crit2=[]
stat3=[]
crit3=[]
stat4=[]
crit4=[]
stat5=[]
crit5=[]
stat6=[]
crit6=[]
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre1_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)

prob = 0.99
critical = chi2.ppf(prob, dof)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
stat1.append(stat)
crit1.append(critical)
if abs(stat) >= critical:
    t1.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t1.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status1', critical,stat,'Independent'])

# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status2', critical,stat,'Independent'])

# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status3', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status3', critical,stat,'Independent'])

# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status4', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status4', critical,stat,'Independent'])
# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status5', critical,stat,'Independent'])
# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre1_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t1.add_row(['Pressure Status6', critical,stat,'Independent'])


# contingency table for LOAD TYPE
table =  pd.crosstab(df['tyre1_condition'], 
                            df['load_type'],  
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t1.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre1_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t1.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre1_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t1.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre1_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat1.append(stat)
crit1.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t1.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t1.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t1)
# Out:
#  CHI 2 ANALYSIS
#
#
#  Tyre 1
#
# tyre1_condition  tyre1_flat  tyre1_not flat
# rainfall
# N                        24             198
# Y                        14              14
# tyre1_condition   tyre1_flat  tyre1_not flat
# tyre1_press_stat
# Correct                    0             212
# High                      18               0
# Low                       20               0
# tyre1_condition   tyre1_flat  tyre1_not flat
# tyre2_press_stat
# Correct                   37             187
# High                       0              14
# Low                        1              11
# tyre1_condition   tyre1_flat  tyre1_not flat
# tyre3_press_stat
# Correct                   38             202
# High                       0               8
# Low                        0               2
# tyre1_condition   tyre1_flat  tyre1_not flat
# tyre4_press_stat
# Correct                   38             205
# High                       0               4
# ...

# %%
print('\n Tyre 2 \n')
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre2_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    t2.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t2.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status1', critical,stat,'Independent'])

table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status2', critical,stat,'Independent'])

table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status3', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status3', critical,stat,'Independent'])

table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status4', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status4', critical,stat,'Independent'])

table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status5', critical,stat,'Independent'])

table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre2_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t2.add_row(['Pressure Status6', critical,stat,'Independent'])


# contingency table for LOAD TYPE
table =  pd.crosstab(df['load_type'],  
                     df['tyre2_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t2.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre2_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t2.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre2_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t2.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre2_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat2.append(stat)
crit2.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t2.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t2.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t2)
# Out:
#  Tyre 2
#
# tyre2_condition  tyre2_flat  tyre2_not flat
# rainfall
# N                        23             199
# Y                         3              25
# tyre2_condition   tyre2_flat  tyre2_not flat
# tyre1_press_stat
# Correct                   25             187
# High                       0              18
# Low                        1              19
# tyre2_condition   tyre2_flat  tyre2_not flat
# tyre2_press_stat
# Correct                    0             224
# High                      14               0
# Low                       12               0
# tyre2_condition   tyre2_flat  tyre2_not flat
# tyre3_press_stat
# Correct                   26             214
# High                       0               8
# Low                        0               2
# tyre2_condition   tyre2_flat  tyre2_not flat
# tyre4_press_stat
# Correct                   26             217
# High                       0               4
# Low                        0               3
# ...

# %%
print('\n Tyre 3 \n')
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre3_condition'],
        
                       margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    t3.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t3.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre3_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status1', critical,stat,'Independent'])



# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre3_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status2', critical,stat,'Independent'])



# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre3_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status', critical,stat,'Independent'])



# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre3_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status4', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status4', critical,stat,'Independent'])



# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre3_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status5', critical,stat,'Independent'])



# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t3.add_row(['Pressure Status6', critical,stat,'Independent'])


# contingency table for LOAD TYPE
table =  pd.crosstab(df['load_type'],
                     df['tyre3_condition'],    
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t3.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre3_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t3.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre3_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t3.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre3_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat3.append(stat)
crit3.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t3.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t3.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t3)
# Out:
#  Tyre 3
#
# tyre3_condition  tyre3_flat  tyre3_not flat
# rainfall
# N                        10             212
# Y                         0              28
# tyre3_condition   tyre3_flat  tyre3_not flat
# tyre1_press_stat
# Correct                   10             202
# High                       0              18
# Low                        0              20
# tyre3_condition   tyre3_flat  tyre3_not flat
# tyre2_press_stat
# Correct                   10             214
# High                       0              14
# Low                        0              12
# tyre3_condition   tyre3_flat  tyre3_not flat
# tyre3_press_stat
# Correct                    0             240
# High                       8               0
# Low                        2               0
# tyre3_condition   tyre3_flat  tyre3_not flat
# tyre4_press_stat
# Correct                    9             234
# High                       1               3
# Low                        0               3
# ...

# %%
print('\n Tyre 4 \n')
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre4_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    t4.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t4.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status1', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status2', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status3', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status3', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status5', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre4_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t4.add_row(['Pressure Status6', critical,stat,'Independent'])


# contingency table for LOAD TYPE
table =  pd.crosstab(df['load_type'],
                     df['tyre4_condition'], 
                            margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t4.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre4_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t4.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre4_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t4.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre4_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat4.append(stat)
crit4.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t4.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t4.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t4)
# Out:
#  Tyre 4
#
# tyre4_condition  tyre4_flat  tyre4_not flat
# rainfall
# N                         6             216
# Y                         1              27
# tyre4_condition   tyre4_flat  tyre4_not flat
# tyre1_press_stat
# Correct                    7             205
# High                       0              18
# Low                        0              20
# tyre4_condition   tyre4_flat  tyre4_not flat
# tyre2_press_stat
# Correct                    7             217
# High                       0              14
# Low                        0              12
# tyre4_condition   tyre4_flat  tyre4_not flat
# tyre3_press_stat
# Correct                    6             234
# High                       1               7
# Low                        0               2
# tyre4_condition   tyre4_flat  tyre4_not flat
# tyre4_press_stat
# Correct                    0             243
# High                       4               0
# Low                        3               0
# ...

# %%
print('\n Tyre 5 \n')
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre5_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    t5.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t5.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status1', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status2', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status3', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status3', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status4', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status4', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status5', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre5_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t5.add_row(['Pressure Status6', critical,stat,'Independent'])


# contingency table for LOAD TYPE
table =  pd.crosstab( df['load_type'],
                            df['tyre5_condition'],  
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t5.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre5_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t5.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre5_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t5.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre5_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat5.append(stat)
crit5.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t5.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t5.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t5)
# Out:
#  Tyre 5
#
# tyre5_condition  tyre5_flat  tyre5_not flat
# rainfall
# N                         3             219
# Y                         0              28
# tyre5_condition   tyre5_flat  tyre5_not flat
# tyre1_press_stat
# Correct                    3             209
# High                       0              18
# Low                        0              20
# tyre5_condition   tyre5_flat  tyre5_not flat
# tyre2_press_stat
# Correct                    3             221
# High                       0              14
# Low                        0              12
# tyre5_condition   tyre5_flat  tyre5_not flat
# tyre3_press_stat
# Correct                    3             237
# High                       0               8
# Low                        0               2
# tyre5_condition   tyre5_flat  tyre5_not flat
# tyre4_press_stat
# Correct                    3             240
# High                       0               4
# Low                        0               3
# ...

# %%
print('\n Tyre 6 \n')
# contingency table for RAINFALL
table =  pd.crosstab(df['rainfall'],
                     df['tyre6_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    t6.add_row(['Rainfall', critical,stat,'Dependent'])
else:
    t6.add_row(['Rainfall', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre1_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status1', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status1', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre2_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status2', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status2', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre3_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status3', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status3', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre4_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status4', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status4', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre5_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status5', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status5', critical,stat,'Independent'])




# contingency table for PRESSURE STATUS   
table =  pd.crosstab(df['tyre6_press_stat'],  
                     df['tyre6_condition'], 
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
##print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Pressure Status6', critical,stat,'Dependent'])
else:
   t6.add_row(['Pressure Status6', critical,stat,'Independent'])





# contingency table for LOAD TYPE
table =  pd.crosstab(df['load_type'],  
                               df['tyre6_condition'], 
                            margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Load Type', critical,stat,'Dependent'])
else:
   t6.add_row(['Load Type', critical,stat,'Independent'])

# contingency table for ROUTE TYPE
table =  pd.crosstab(df['route_type'],  
                     df['tyre6_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Route Type', critical,stat,'Dependent'])
else:
   t6.add_row(['Route Type', critical,stat,'Independent'])


# contingency table for TRUCK TYPE
table =  pd.crosstab( df['truck_type'], 
                      df['tyre6_condition'],
                               margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Truck type', critical,stat,'Dependent'])
else:
   t6.add_row(['Truck type', critical,stat,'Independent'])

# contingency table for TEMPERATURE TYPE
table =  pd.crosstab(df['temp_type'], 
                     df['tyre6_condition'], 
                      margins = False) 
print(table)
stat, p, dof, expected = chi2_contingency(table)
#print('dof=%d' % dof)
#print(expected)
# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
stat6.append(stat)
crit6.append(critical)
#print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
   t6.add_row(['Temperature Type', critical,stat,'Dependent'])
else:
   t6.add_row(['Temperature Type', critical,stat,'Independent'])

np.set_printoptions(precision=4)

print(t6)
# Out:
#  Tyre 6
#
# tyre6_condition  tyre6_flat  tyre6_not flat
# rainfall
# N                         2             220
# Y                         0              28
# tyre6_condition   tyre6_flat  tyre6_not flat
# tyre1_press_stat
# Correct                    2             210
# High                       0              18
# Low                        0              20
# tyre6_condition   tyre6_flat  tyre6_not flat
# tyre2_press_stat
# Correct                    2             222
# High                       0              14
# Low                        0              12
# tyre6_condition   tyre6_flat  tyre6_not flat
# tyre3_press_stat
# Correct                    2             238
# High                       0               8
# Low                        0               2
# tyre6_condition   tyre6_flat  tyre6_not flat
# tyre4_press_stat
# Correct                    2             241
# High                       0               4
# Low                        0               3
# ...

# %%
stat6
# Out:
# [0.3860517343380247,
#  0.36138161898965304,
#  0.23401497695852536,
#  0.08400537634408603,
#  0.058077791052701451,
#  0.02448739715293196,
#  249.99999999999997,
#  6.8265421618562536,
#  1.4227703025823839,
#  0.55389969138352735,
#  0.36138161898965304]

# %%
stat2
# Out:
# [0.073262559311666392,
#  3.156262958739374,
#  250.00000000000006,
#  1.2090773809523809,
#  0.83590534979423869,
#  0.35244360902255645,
#  0.2340149769585253,
#  4.0419679215124384,
#  10.719559668767891,
#  0.0060721788937241556,
#  3.1562629587393745]

# %%
feature_dict = {i:label for i,label in zip(
                  ('rainfall',
                   'tyre1_press_stat',
                   'tyre2_press_stat',
                   'tyre3_press_stat',
                   'tyre4_press_stat',
                   'tyre5_press_stat',
                   'tyre6_press_stat',
                      'load_type',
                   'route_type',
                   'truck_type',
                   'temp_type',
                   ),stat1)}
print(feature_dict)
final_df=pd.DataFrame()
final_df['Feature']=['rainfall',
                   'tyre1_press_stat',
                   'tyre2_press_stat',
                   'tyre3_press_stat',
                   'tyre4_press_stat',
                   'tyre5_press_stat',
                   'tyre6_press_stat',
                      'load_type',
                   'route_type',
                   'truck_type',
                   'temp_type',]
final_df['Stat1'] = final_df['Feature'].map(feature_dict)

print(final_df)
# Out:
# {'rainfall': 26.663026007458726, 'tyre1_press_stat': 250.0, 'tyre2_press_stat': 3.250220923771693, 'tyre3_press_stat': 1.8671383647798749, 'tyre4_press_stat': 1.2908610916996661, 'tyre5_press_stat': 0.54426705370101602, 'tyre6_press_stat': 0.3613816189896531, 'load_type': 9.6127872057405099, 'route_type': 2.1475118303217848, 'truck_type': 0.51891061048582054, 'temp_type': 249.99999999999997}
#              Feature       Stat1
# 0           rainfall   26.663026
# 1   tyre1_press_stat  250.000000
# 2   tyre2_press_stat    3.250221
# 3   tyre3_press_stat    1.867138
# 4   tyre4_press_stat    1.290861
# 5   tyre5_press_stat    0.544267
# 6   tyre6_press_stat    0.361382
# 7          load_type    9.612787
# 8         route_type    2.147512
# 9         truck_type    0.518911
# 10         temp_type  250.000000

# %%
final_df['Crit1']=crit1
final_df['Stat2']=stat2
final_df['Crit2']=crit2
final_df['Stat3']=stat3
final_df['Crit3']=crit3
final_df['Stat4']=stat4
final_df['Crit4']=crit4
final_df['Stat5']=stat5
final_df['Crit5']=crit5
final_df['Stat6']=stat6
final_df['Crit6']=crit6

# %%
final_df
# Out:
#              Feature       Stat1     Crit1       Stat2     Crit2       Stat3  \
# 0           rainfall   26.663026  6.634897    0.073263  6.634897    0.402607
# 1   tyre1_press_stat  250.000000  9.210340    3.156263  9.210340    1.867138
# 2   tyre2_press_stat    3.250221  9.210340  250.000000  9.210340    1.209077
# 3   tyre3_press_stat    1.867138  9.210340    1.209077  9.210340  250.000000
# 4   tyre4_press_stat    1.290861  9.210340    0.835905  9.210340    4.774306
# 5   tyre5_press_stat    0.544267  9.210340    0.352444  9.210340    0.126518
# 6   tyre6_press_stat    0.361382  9.210340    0.234015  9.210340  250.000000
# 7          load_type    9.612787  9.210340    4.041968  9.210340   13.188937
# 8         route_type    2.147512  9.210340   10.719560  9.210340    2.912857
# 9         truck_type    0.518911  6.634897    0.006072  6.634897    1.094130
# 10         temp_type  250.000000  9.210340    3.156263  9.210340    1.867138
#
# ...
