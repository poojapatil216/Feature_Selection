# %%
import pandas as pd
import numpy as np
from scipy import stats 
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
df = pd.read_csv('test_data.csv')
feature_dict = {i:label for i,label in zip(
                range(21),
                  ('load_type',
                   'truck_type',
                   'route_type',
                   'rainfall',
                   'temperature',
                   'temp_type',
                   'tyre1_press',
                   'tyre1_press_stat',
                   'tyre2_press',
                   'tyre2_press_stat',
                   'tyre3_press',
                   'tyre3_press_stat',
                   'tyre4_press',
                   'tyre4_press_stat',
                   'tyre5_press',
                   'tyre5_press_stat',
                   'tyre6_press',
                   'tyre6_press_stat',
                   'avg_speed',
                   'time',
                   'fuel',
                   ))}

df.columns = [l for i,l in sorted(feature_dict.items())] + [
                   'tyre1_condition',
                   'tyre2_condition',
                   'tyre3_condition',
                   'tyre4_condition',
                   'tyre5_condition',
                   'tyre6_condition',
                   'efficiency',      ]
df.dropna(how="all", inplace=True) # to drop the empty line at file-end

df.tail()
# Out:
#       load_type truck_type route_type rainfall  temperature temp_type  \
# 245  Heavy Load        FTL      Bumpy        N           26    Normal
# 246  Heavy Load        FTL      Bumpy        N           33    Normal
# 247    Moderate        LCV      Hilly        N           27    Normal
# 248    Moderate        FTL      Bumpy        N           25    Normal
# 249   Full Load        LCV      Plain        N           31    Normal
#
#      tyre1_press tyre1_press_stat  tyre2_press tyre2_press_stat     ...      \
# 245           61          Correct           47          Correct     ...
# 246           35          Correct           50          Correct     ...
# 247           50          Correct           58          Correct     ...
# 248           38          Correct           55          Correct     ...
# 249           41          Correct           36          Correct     ...
#
#      avg_speed time  fuel tyre1_condition  tyre2_condition tyre3_condition  \
# ...

# %%
final_df1=pd.DataFrame()
final_df1['Feature']=['Temperature',
                     'Tyre 1 Pressure',
                     'Tyre 2 Pressure',
                     'Tyre 3 Pressure',
                     'Tyre 4 Pressure',
                     'Tyre 5 Pressure',
                     'Tyre 6 Pressure',
                     'Average Speed',
                     'Time',
                     'Fuel',]
scores=[]
pvalues=[]

# %%
print('Temperature')
y=df['efficiency'].values.reshape(-1,1)
X=df['temperature'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)

scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 1 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre1_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 2 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre2_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 3 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre3_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 4 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre4_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 5 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre5_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Tyre 6 Pressure')
y=df['efficiency'].values.reshape(-1,1)
X=df['tyre6_press'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Average')
y=df['efficiency'].values.reshape(-1,1)
X=df['avg_speed'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Time')
y=df['efficiency'].values.reshape(-1,1)
X=df['time'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))

print('Fuel')
y=df['efficiency'].values.reshape(-1,1)
X=df['fuel'].values.reshape(-1,1)
X= StandardScaler().fit_transform(X)
y= StandardScaler().fit_transform(y)

fscores,p_values=f_regression(X,y)
scores.append(float(fscores))
pvalues.append(float(p_values))
# Out:
# Temperature
# Tyre 1 Pressure
# Tyre 2 Pressure
# Tyre 3 Pressure
# Tyre 4 Pressure
# Tyre 5 Pressure
# Tyre 6 Pressure
# Average
# Time
# Fuel
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
final_df1['F_Scores'] = scores
final_df1['P_Values']=pvalues

# %%
y_new=pd.DataFrame()
X = df['efficiency'].values
X= StandardScaler().fit_transform(X)

y = df['load_type'].values
y_new['load_type']=y
cleanup_nums = {"load_type":     {"Heavy Load": 1, "Moderate": 0, "Full Load": 0.5}}
y_new.replace(cleanup_nums, inplace=True)

y = df['temp_type'].values
y_new['temp_type']=y
cleanup_nums = { "temp_type": {"Low": 0, "Normal": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre1_press_stat'].values
y_new['tyre1_press_stat']=y
cleanup_nums = { "tyre1_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre2_press_stat'].values
y_new['tyre2_press_stat']=y
cleanup_nums = { "tyre2_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre3_press_stat'].values
y_new['tyre3_press_stat']=y
cleanup_nums = { "tyre3_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre4_press_stat'].values
y_new['tyre4_press_stat']=y
cleanup_nums = { "tyre4_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre5_press_stat'].values
y_new['tyre5_press_stat']=y
cleanup_nums = { "tyre5_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)


y = df['tyre6_press_stat'].values
y_new['tyre6_press_stat']=y
cleanup_nums = { "tyre6_press_stat": {"Low": 0, "Correct": 0.5, "High": 1}}
y_new.replace(cleanup_nums, inplace=True)
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
scores,pvalues=f_regression(y_new,X)

Final_features=pd.DataFrame()
Final_features['Feature']=['Load Type',
                   'Temp Type',
                   'Tyre1 Press Stat',
                   'Tyre2 Press Stat',
                   'Tyre3 Press Stat',
                   'Tyre4 Press Stat',
                   'Tyre5 Press Stat',
                   'Tyre6 Press Stat',
                   ]
Final_features['F_Scores'] = scores
Final_features['P_Values'] = pvalues

# %%
y_new=pd.DataFrame()
X = df['efficiency'].values

y = df['truck_type'].values
y_new['truck_type']=y


y_new = pd.concat([y_new.drop('truck_type', axis=1), pd.get_dummies(df['truck_type'])], axis=1)
y = df['route_type'].values
y_new['route_type']=y
y_new = pd.concat([y_new.drop('route_type', axis=1), pd.get_dummies(df['route_type'])], axis=1)

y = df['rainfall'].values
y_new['rainfall']=y
y_new = pd.concat([y_new.drop('rainfall', axis=1), pd.get_dummies(df['rainfall'])], axis=1)
y_new.head()

scores,pvalues=f_regression(y_new,X)

# %%
Final_features2=pd.DataFrame()
Final_features2['Feature']=['FTL',
                   'LCV',
                   'Bumpy',
                   'Hilly',
                   'Plain',
                   'N',
                   'Y',]
Final_features2['F_Scores'] = scores
Final_features2['P_Values'] = pvalues

# %%
final_df2=pd.DataFrame()
final_df2=Final_features.append(Final_features2, ignore_index = True)

# %%
results_df=pd.DataFrame()
results_df=final_df1.append(final_df2, ignore_index = True)

results_df=results_df.sort_values(by=['F_Scores','P_Values'],ascending=[False,True])
results_df['Rank']=range(1,26)

results_df=results_df.sort_index(axis = 0) 
results_df=results_df.round(3)
results_df
# Out:
#              Feature  F_Scores  P_Values  Rank
# 0        Temperature     0.170     0.681    12
# 1    Tyre 1 Pressure     0.335     0.563     9
# 2    Tyre 2 Pressure     1.541     0.216     6
# 3    Tyre 3 Pressure     0.135     0.713    15
# 4    Tyre 4 Pressure     0.146     0.703    13
# 5    Tyre 5 Pressure     0.403     0.526     8
# 6    Tyre 6 Pressure     1.079     0.300     7
# 7      Average Speed     0.007     0.931    21
# 8               Time     0.102     0.750    19
# 9               Fuel     2.176     0.141     3
# 10         Load Type     0.016     0.901    20
# 11         Temp Type     0.129     0.720    16
# 12  Tyre1 Press Stat     0.129     0.720    17
# 13  Tyre2 Press Stat     2.559     0.111     2
# 14  Tyre3 Press Stat     0.203     0.653    10
# 15  Tyre4 Press Stat     0.002     0.962    22
# 16  Tyre5 Press Stat     0.110     0.740    18
# 17  Tyre6 Press Stat     4.867     0.028     1
# 18               FTL     1.980     0.161     4
# ...
